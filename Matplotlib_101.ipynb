# %% [markdown]
# ![cheatsheets-1.png](attachment:cheatsheets-1.png)

# %% [markdown]
# ![cheatsheets-2.png](attachment:cheatsheets-2.png)

# %% [markdown]
# ![handout-beginner.png](attachment:handout-beginner.png)

# %% [markdown]
# ![handout-intermediate.png](attachment:handout-intermediate.png)

# %% [markdown]
# ![handout-tips.png](attachment:handout-tips.png)
